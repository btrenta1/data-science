# %% [markdown]
# <a href="https://colab.research.google.com/github/btrenta1/data-science/blob/main/Brandon_Trenta2023_Lab_1_hw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stats Notebook Lab #1

# %% [markdown]
# ## Python Basics

# %% [markdown]
# ### Calculator

# %%
# Comment lksjadflkasjdlfkjasd;lkfjl;kdsfkjshadfjkhasdkjflhsadkjfhskjdkjvjx

# %%
30.34321 + 9.12313 - 3.5567
# Out:
# 35.90964

# %%
2*2 # 2 times 2
# Out:
# 4

# %%
2**8 #2 squared by 8
# Out:
# 256

# %%
2**123 #2 squared by 123
# Out:
# 10633823966279326983230456482242756608

# %%
2**12345 # 2 squared by 12345
# Out:
# ...

# %%
123**45678 #125 squared by 45678
# Out:
# ...

# %%
8/4 # 8 divided by 4
# Out:
# 2.0

# %%
8//4 # 8 divided by 4
# Out:
# 2

# %%
8%12 # cannot figure out what this does
# Out:
# 8

# %%
13%12
# Out:
# 1

# %%
22%12
# Out:
# 10

# %%
24%12
# Out:
# 0

# %% [markdown]
# ### Variables

# %%
apples = 5 # first variable

# %%
oranges = 8 # second variable

# %%
total = apples + oranges #both variables added equals the total

# %%
total # testing the total
# Out:
# 13

# %%
apples**2 # first variable squared
# Out:
# 25

# %%
cost_per_apple = 0.25 # setting another variable which is cost of each apple to be 25 cents

# %%
total_apple_costs = cost_per_apple * apples # another variable added

# %%
total_apple_costs # apples (5) times cost per apple (.25)
# Out:
# 1.25

# %% [markdown]
# ### Vectors

# %%
import numpy as np
import matplotlib.pyplot as plt. #importing numpy which works with array, importing matplotlib which plots
# Out:
#   File "<ipython-input-63-2a1aa2943af5>", line 2
#     import matplotlib.pyplot as plt. #importing numpy which works with array, importing matplotlib which plots
#                                    ^
# SyntaxError: invalid syntax

# %%
np.arange(10) #arange 10

# %%
x = np.arange(10) # varibale x equals arange 10

# %%
x # testing variable

# %%
y = 3 * x + 5 #y is 3 times x plus 5

# %%
y #testing variable

# %%
x = np.array([1,2,3,4,5,6])
y = np.array([11,22,33,44,55,66]). # data for plots

# %%
plt.plot(x,y). #plot the points from above

# %%
plt.plot(x,y,'.') # same plot but the '.' means dotted line

# %%
plt.plot(x,y,'r.') #'r.' means red dotted line

# %%
plt.plot(x,y,'b--') "b--" means blue dashed line

# %% [markdown]
# ### Plotting

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y) #plot the points from above

# %%
x = np.linspace(0,10,100) # arange 0 through 10 with 100 different numbers in order

# %%
x

# %%
y = x**2 #y equals x squared by 2

# %%
plt.plot(x,y) #plot the points from above

# %%
plt.plot(x,y).  # plot it
plt.title("Graph of x**2"); # sets the title
plt.xlabel("x"); #label x axis x
plt.ylabel("y"); #label y axis y

# %%
plt.plot(x,y,label="x squared") #stats what the line represents
plt.title("Graph of x**2"); # title
plt.xlabel("x"); # label of x axis
plt.ylabel("y"); #label of y axis
plt.legend()

# %%
x = np.linspace(0, 2, 100) # start at 0 go to 2 and end up at 100 on the y axis 

plt.plot(x, x, label='linear') # 'linear ' name of first line 
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**8, label='cubic')

plt.xlabel('x label') # title of x axis
plt.ylabel('y label') #title of y axis

plt.title("Simple Plot") #title

plt.legend() #adds legend

# %%
t = np.arange(0., 5., 0.2) 
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^');

# %%
names = ['cat', 'dog', 'bird']
values = [15, 18, 6]

plt.figure(1, figsize=(9, 3))


plt.subplot(131)
plt.bar(names, values)

plt.subplot(132)
plt.scatter(names, values)

plt.subplot(133)
plt.plot(names, values)


plt.suptitle('Categorical Plotting')
plt.show()

# %% [markdown]
# https://matplotlib.org/stable/gallery/index.html

# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.arange(0.0, 2.0, 0.01)
s = np.sin(2*np.pi*t)

plt.plot(t, s)
plt.title(r'$\alpha_i > \beta_i$', fontsize=20)
plt.text(1, -0.6, r'$\sum_{i=0}^\infty x_i$', fontsize=20)
plt.text(0.5, 0.6, r'$\mathcal{A}\mathrm{sin}(2 \omega t)$',fontsize=15)
plt.xlabel('time (s)')
plt.ylabel('volts (mV)')
plt.show()

# %% [markdown]
# # Exercises

# %% [markdown]
# Plot the following functions from $x = -10$ to $x = 10$
#
# (Hint: np.sin, np.exp)

# %% [markdown]
# $y = 10x+7$
#
# $y = -3x-12$
#
# $y=\sin(x)$
#
# $y=e^x$
#
# $y=e^{-x^2}$

# %% [markdown]
# Pick out a plot of your choice from [here](https://matplotlib.org/stable/gallery/index.html), copy the code to this notebook, run, and document to the best of your abilities.

# %%
import numpy as np

# %%
x = np.linspace(-10,10)

# %%
import matplotlib.pyplot as plt

# %%
x
# Out:
# array([-10.        ,  -9.59183673,  -9.18367347,  -8.7755102 ,
#         -8.36734694,  -7.95918367,  -7.55102041,  -7.14285714,
#         -6.73469388,  -6.32653061,  -5.91836735,  -5.51020408,
#         -5.10204082,  -4.69387755,  -4.28571429,  -3.87755102,
#         -3.46938776,  -3.06122449,  -2.65306122,  -2.24489796,
#         -1.83673469,  -1.42857143,  -1.02040816,  -0.6122449 ,
#         -0.20408163,   0.20408163,   0.6122449 ,   1.02040816,
#          1.42857143,   1.83673469,   2.24489796,   2.65306122,
#          3.06122449,   3.46938776,   3.87755102,   4.28571429,
#          4.69387755,   5.10204082,   5.51020408,   5.91836735,
#          6.32653061,   6.73469388,   7.14285714,   7.55102041,
#          7.95918367,   8.36734694,   8.7755102 ,   9.18367347,
#          9.59183673,  10.        ])

# %%
y = 10* x + 7

# %%
plt.plot(x,y,label="y =10x +7") #stats what the line represents
plt.title("Graph of y = 10x+7"); # title
plt.xlabel("x"); # label of x axis
plt.ylabel("y"); #label of y axis
plt.legend()

# %%
y2 = -3* x -12

# %%
plt.plot(x,y2,label="y = -3x -12") #stats what the line represents
plt.title("Graph of y = -3x -12"); # title
plt.xlabel("x"); # label of x axis
plt.ylabel("y"); #label of y axis
plt.legend()

# %%
y3 = np.sin(x)

# %%
plt.plot(x,y3,label="y = sin(x)") #stats what the line represents
plt.title("Graph of y = sin(x)"); # title
plt.xlabel("x"); # label of x axis
plt.ylabel("y"); #label of y axis
plt.legend()

# %%
y4 = np.exp(x)

# %%
plt.plot(x,y4,label="y = e^x") #stats what the line represents
plt.title("Graph of y = e^x"); # title
plt.xlabel("x"); # label of x axis
plt.ylabel("y"); #label of y axis
plt.legend()

# %%
y5 = np.exp(-x**2)

# %%
plt.plot(x,y5,label="y = e^-x**2") #stats what the line represents
plt.title("Graph of y = e^-x**2"); # title
plt.xlabel("x"); # label of x axis
plt.ylabel("y"); #label of y axis
plt.legend()
